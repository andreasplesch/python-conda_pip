# %%
import x3d
# Out:
# x3d package loaded, have fun with X3D Graphics!

# %%
help(x3d)
# Out:
# Help on module x3d:
#
# NAME
#     x3d - ###############################################
#
# CLASSES
#     _X3DAppearanceChildNode(_X3DNode)
#         FillProperties
#         LineProperties
#         PointProperties
#     _X3DAppearanceNode(_X3DNode)
#         Appearance
#     _X3DBackgroundNode(_X3DBindableNode)
#         Background
#         TextureBackground
#     _X3DBindableNode(_X3DChildNode)
#         Fog
#         NavigationInfo
#     _X3DChaserNode(_X3DFollowerNode)
#         ColorChaser
#         CoordinateChaser
#         OrientationChaser
#         PositionChaser
#         PositionChaser2D
#         ScalarChaser
#         TexCoordChaser2D
#     _X3DChildNode(_X3DNode)
#         BooleanFilter
#         BooleanToggle
#         ClipPlane
#         DISEntityManager
#         EaseInEaseOut
#         GeoLOD
#         HAnimHumanoid
#         HAnimJoint
#         HAnimMotion
#         Inline
#         LocalFog
#         NurbsOrientationInterpolator
# ...

# %%
x3dDoc = x3d.X3D()

# %%
scene = x3d.Scene()

# %%
x3dDoc.scene = scene

# %%
# are routes in a separate attribute ? Let's see

# %%
scene.routes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-6ca6c85a8e49> in <module>
# ----> 1 scene.routes
#
# AttributeError: 'Scene' object has no attribute 'routes'

# %%
scene.Routes
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-68ba2e82cdc7> in <module>
# ----> 1 scene.Routes
#
# AttributeError: 'Scene' object has no attribute 'Routes'

# %%
help(x3d.Scene)
# Out:
# Help on class Scene in module x3d:
#
# class Scene(_X3DStatement)
#  |  Scene(children=[])
#  |
#  |  Scene is the implicit root node of the X3D scene graph.
#  |
#  |  Method resolution order:
#  |      Scene
#  |      _X3DStatement
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, children=[])
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  FIELD_DECLARATIONS = [('children', [], 'MFNode', 'inputOutput')]
#  |
#  |  specificationUrl = 'https://www.web3d.org/documents/specifications/197...
#  |
#  |  tooltip = 'https://www.web3d.org/x3d/tooltips/X3dTooltips.html#Scene'
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from _X3DStatement:
#  |
#  |  __repl__(self)
#  |
#  |  __str__(self)
#  |      Return str(self).
#  |
# ...

# %%
# no, scene can only have children
